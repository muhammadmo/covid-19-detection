# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadmo/covid-19-detection/blob/main/IOT_framework_(CXR_data_%2B_InceptionResNetV2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.63.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-880d487c-3b6c-4e86-830f-eef8dee9194c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-880d487c-3b6c-4e86-830f-eef8dee9194c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"muhammadmoosavi","key":"1fa1bc8aae4bfd517b860f44615ff8d9"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d sachinkumar413/covid-pneumonia-normal-chest-xray-images
# Out:
# Downloading covid-pneumonia-normal-chest-xray-images.zip to /content
#  96% 265M/277M [00:02<00:00, 164MB/s]
# 100% 277M/277M [00:02<00:00, 138MB/s]

# %%
from zipfile import ZipFile
file_name = "covid-pneumonia-normal-chest-xray-images.zip"

with ZipFile(file_name,'r') as zipp:
  zipp.extractall()
print('done')
# Out:
# done

# %%
pip install split_folders
# Out:
# Collecting split_folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders
input_folder = "/content/dataset"
output = "/content/splited_dataset"

splitfolders.ratio(input_folder, output=output, seed=42, ratio=(.7, .1, .2))
# Out:
# Copying files: 5228 files [00:01, 3096.16 files/s]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

train_path = '/content/splited_dataset/train'
test_path = '/content/splited_dataset/test'
valid_path = '/content/splited_dataset/val'

#set defult image size
batch_size = 16
img_width = 229
img_height = 229
#img_channel = 3

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Create Image Data Generator for Train Set
image_gen = ImageDataGenerator(
                                rotation_range=15,
                                width_shift_range=0.05,
                                height_shift_range=0.05,
                                rescale = 1./255,
                                shear_range = 0.2,
                                zoom_range = 0.2,
                                horizontal_flip = True,
                               )
# Create Image Data Generator for Test/Validation Set
test_data_gen = ImageDataGenerator(rescale = 1./255)

# %%
train = image_gen.flow_from_directory(
      train_path,
      target_size=(img_height, img_width),
      color_mode='rgb',
      class_mode='sparse',
      batch_size=batch_size
      )
test = test_data_gen.flow_from_directory(
      test_path,
      target_size=(img_height, img_width),
      color_mode='rgb',
      shuffle=False,
#setting shuffle as False just so we can later compare it with predicted values without having indexing problem
      class_mode='sparse',
      batch_size=batch_size
      )
valid = test_data_gen.flow_from_directory(
      valid_path,
      target_size=(img_height, img_width),
      color_mode='rgb',
      class_mode='sparse',
      batch_size=batch_size
      )
# Out:
# Found 3659 images belonging to 3 classes.
# Found 1047 images belonging to 3 classes.
# Found 522 images belonging to 3 classes.

# %%
from tensorflow.keras.applications import InceptionResNetV2

conv_base = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(229, 229, 3))

conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 2s 0us/step
# 219070464/219055592 [==============================] - 2s 0us/step
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 229, 229, 3  0           []
#                                 )]
#
#  conv2d_285 (Conv2D)            (None, 114, 114, 32  864         ['input_4[0][0]']
#                                 )
#
#  batch_normalization_282 (Batch  (None, 114, 114, 32  96         ['conv2d_285[0][0]']
#  Normalization)                 )
#
#  activation_282 (Activation)    (None, 114, 114, 32  0           ['batch_normalization_282[0][0]']
#                                 )
#
#  conv2d_286 (Conv2D)            (None, 112, 112, 32  9216        ['activation_282[0][0]']
#                                 )
#
#  batch_normalization_283 (Batch  (None, 112, 112, 32  96         ['conv2d_286[0][0]']
#  Normalization)                 )
#
#  activation_283 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_283[0][0]']
#                                 )
#
#  conv2d_287 (Conv2D)            (None, 112, 112, 64  18432       ['activation_283[0][0]']
#                                 )
#
#  batch_normalization_284 (Batch  (None, 112, 112, 64  192        ['conv2d_287[0][0]']
#  Normalization)                 )
#
#  activation_284 (Activation)    (None, 112, 112, 64  0           ['batch_normalization_284[0][0]']
#                                 )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 55, 55, 64)  0           ['activation_284[0][0]']
#  )
#
#  conv2d_288 (Conv2D)            (None, 55, 55, 80)   5120        ['max_pooling2d_12[0][0]']
#
#  batch_normalization_285 (Batch  (None, 55, 55, 80)  240         ['conv2d_288[0][0]']
#  Normalization)
#
#  activation_285 (Activation)    (None, 55, 55, 80)   0           ['batch_normalization_285[0][0]']
#
#  conv2d_289 (Conv2D)            (None, 53, 53, 192)  138240      ['activation_285[0][0]']
#
#  batch_normalization_286 (Batch  (None, 53, 53, 192)  576        ['conv2d_289[0][0]']
#  Normalization)
#
#  activation_286 (Activation)    (None, 53, 53, 192)  0           ['batch_normalization_286[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 26, 26, 192)  0          ['activation_286[0][0]']
#  )
#
#  conv2d_293 (Conv2D)            (None, 26, 26, 64)   12288       ['max_pooling2d_13[0][0]']
#
#  batch_normalization_290 (Batch  (None, 26, 26, 64)  192         ['conv2d_293[0][0]']
#  Normalization)
#
#  activation_290 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_290[0][0]']
#
#  conv2d_291 (Conv2D)            (None, 26, 26, 48)   9216        ['max_pooling2d_13[0][0]']
#
#  conv2d_294 (Conv2D)            (None, 26, 26, 96)   55296       ['activation_290[0][0]']
#
#  batch_normalization_288 (Batch  (None, 26, 26, 48)  144         ['conv2d_291[0][0]']
#  Normalization)
#
#  batch_normalization_291 (Batch  (None, 26, 26, 96)  288         ['conv2d_294[0][0]']
#  Normalization)
#
#  activation_288 (Activation)    (None, 26, 26, 48)   0           ['batch_normalization_288[0][0]']
#
#  activation_291 (Activation)    (None, 26, 26, 96)   0           ['batch_normalization_291[0][0]']
#
#  average_pooling2d_27 (AverageP  (None, 26, 26, 192)  0          ['max_pooling2d_13[0][0]']
#  ooling2D)
#
#  conv2d_290 (Conv2D)            (None, 26, 26, 96)   18432       ['max_pooling2d_13[0][0]']
#
#  conv2d_292 (Conv2D)            (None, 26, 26, 64)   76800       ['activation_288[0][0]']
#
#  conv2d_295 (Conv2D)            (None, 26, 26, 96)   82944       ['activation_291[0][0]']
#
#  conv2d_296 (Conv2D)            (None, 26, 26, 64)   12288       ['average_pooling2d_27[0][0]']
#
#  batch_normalization_287 (Batch  (None, 26, 26, 96)  288         ['conv2d_290[0][0]']
#  Normalization)
#
#  batch_normalization_289 (Batch  (None, 26, 26, 64)  192         ['conv2d_292[0][0]']
#  Normalization)
#
#  batch_normalization_292 (Batch  (None, 26, 26, 96)  288         ['conv2d_295[0][0]']
#  Normalization)
#
#  batch_normalization_293 (Batch  (None, 26, 26, 64)  192         ['conv2d_296[0][0]']
#  Normalization)
#
#  activation_287 (Activation)    (None, 26, 26, 96)   0           ['batch_normalization_287[0][0]']
#
#  activation_289 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_289[0][0]']
#
#  activation_292 (Activation)    (None, 26, 26, 96)   0           ['batch_normalization_292[0][0]']
#
#  activation_293 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_293[0][0]']
#
#  mixed_5b (Concatenate)         (None, 26, 26, 320)  0           ['activation_287[0][0]',
#                                                                   'activation_289[0][0]',
#                                                                   'activation_292[0][0]',
#                                                                   'activation_293[0][0]']
#
#  conv2d_300 (Conv2D)            (None, 26, 26, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_297 (Batch  (None, 26, 26, 32)  96          ['conv2d_300[0][0]']
#  Normalization)
#
#  activation_297 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_297[0][0]']
#
#  conv2d_298 (Conv2D)            (None, 26, 26, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_301 (Conv2D)            (None, 26, 26, 48)   13824       ['activation_297[0][0]']
#
#  batch_normalization_295 (Batch  (None, 26, 26, 32)  96          ['conv2d_298[0][0]']
#  Normalization)
#
#  batch_normalization_298 (Batch  (None, 26, 26, 48)  144         ['conv2d_301[0][0]']
#  Normalization)
#
#  activation_295 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_295[0][0]']
#
#  activation_298 (Activation)    (None, 26, 26, 48)   0           ['batch_normalization_298[0][0]']
#
#  conv2d_297 (Conv2D)            (None, 26, 26, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_299 (Conv2D)            (None, 26, 26, 32)   9216        ['activation_295[0][0]']
#
#  conv2d_302 (Conv2D)            (None, 26, 26, 64)   27648       ['activation_298[0][0]']
#
#  batch_normalization_294 (Batch  (None, 26, 26, 32)  96          ['conv2d_297[0][0]']
#  Normalization)
#
#  batch_normalization_296 (Batch  (None, 26, 26, 32)  96          ['conv2d_299[0][0]']
#  Normalization)
#
#  batch_normalization_299 (Batch  (None, 26, 26, 64)  192         ['conv2d_302[0][0]']
#  Normalization)
#
#  activation_294 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_294[0][0]']
#
#  activation_296 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_296[0][0]']
#
#  activation_299 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_299[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 26, 26, 128)  0           ['activation_294[0][0]',
#                                                                   'activation_296[0][0]',
#                                                                   'activation_299[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 26, 26, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 26, 26, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 26, 26, 320)  0           ['block35_1[0][0]']
#
#  conv2d_306 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_303 (Batch  (None, 26, 26, 32)  96          ['conv2d_306[0][0]']
#  Normalization)
#
#  activation_303 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_303[0][0]']
#
#  conv2d_304 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_307 (Conv2D)            (None, 26, 26, 48)   13824       ['activation_303[0][0]']
#
#  batch_normalization_301 (Batch  (None, 26, 26, 32)  96          ['conv2d_304[0][0]']
#  Normalization)
#
#  batch_normalization_304 (Batch  (None, 26, 26, 48)  144         ['conv2d_307[0][0]']
#  Normalization)
#
#  activation_301 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_301[0][0]']
#
#  activation_304 (Activation)    (None, 26, 26, 48)   0           ['batch_normalization_304[0][0]']
#
#  conv2d_303 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_305 (Conv2D)            (None, 26, 26, 32)   9216        ['activation_301[0][0]']
#
#  conv2d_308 (Conv2D)            (None, 26, 26, 64)   27648       ['activation_304[0][0]']
#
#  batch_normalization_300 (Batch  (None, 26, 26, 32)  96          ['conv2d_303[0][0]']
#  Normalization)
#
#  batch_normalization_302 (Batch  (None, 26, 26, 32)  96          ['conv2d_305[0][0]']
#  Normalization)
#
#  batch_normalization_305 (Batch  (None, 26, 26, 64)  192         ['conv2d_308[0][0]']
#  Normalization)
#
#  activation_300 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_300[0][0]']
#
#  activation_302 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_302[0][0]']
#
#  activation_305 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_305[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 26, 26, 128)  0           ['activation_300[0][0]',
#                                                                   'activation_302[0][0]',
#                                                                   'activation_305[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 26, 26, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 26, 26, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 26, 26, 320)  0           ['block35_2[0][0]']
#
#  conv2d_312 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_309 (Batch  (None, 26, 26, 32)  96          ['conv2d_312[0][0]']
#  Normalization)
#
#  activation_309 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_309[0][0]']
#
#  conv2d_310 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_313 (Conv2D)            (None, 26, 26, 48)   13824       ['activation_309[0][0]']
#
#  batch_normalization_307 (Batch  (None, 26, 26, 32)  96          ['conv2d_310[0][0]']
#  Normalization)
#
#  batch_normalization_310 (Batch  (None, 26, 26, 48)  144         ['conv2d_313[0][0]']
#  Normalization)
#
#  activation_307 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_307[0][0]']
#
#  activation_310 (Activation)    (None, 26, 26, 48)   0           ['batch_normalization_310[0][0]']
#
#  conv2d_309 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_311 (Conv2D)            (None, 26, 26, 32)   9216        ['activation_307[0][0]']
#
#  conv2d_314 (Conv2D)            (None, 26, 26, 64)   27648       ['activation_310[0][0]']
#
#  batch_normalization_306 (Batch  (None, 26, 26, 32)  96          ['conv2d_309[0][0]']
#  Normalization)
#
#  batch_normalization_308 (Batch  (None, 26, 26, 32)  96          ['conv2d_311[0][0]']
#  Normalization)
#
#  batch_normalization_311 (Batch  (None, 26, 26, 64)  192         ['conv2d_314[0][0]']
#  Normalization)
#
#  activation_306 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_306[0][0]']
#
#  activation_308 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_308[0][0]']
#
#  activation_311 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_311[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 26, 26, 128)  0           ['activation_306[0][0]',
#                                                                   'activation_308[0][0]',
#                                                                   'activation_311[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 26, 26, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 26, 26, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 26, 26, 320)  0           ['block35_3[0][0]']
#
#  conv2d_318 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_315 (Batch  (None, 26, 26, 32)  96          ['conv2d_318[0][0]']
#  Normalization)
#
#  activation_315 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_315[0][0]']
#
#  conv2d_316 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_319 (Conv2D)            (None, 26, 26, 48)   13824       ['activation_315[0][0]']
#
#  batch_normalization_313 (Batch  (None, 26, 26, 32)  96          ['conv2d_316[0][0]']
#  Normalization)
#
#  batch_normalization_316 (Batch  (None, 26, 26, 48)  144         ['conv2d_319[0][0]']
#  Normalization)
#
#  activation_313 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_313[0][0]']
#
#  activation_316 (Activation)    (None, 26, 26, 48)   0           ['batch_normalization_316[0][0]']
#
#  conv2d_315 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_317 (Conv2D)            (None, 26, 26, 32)   9216        ['activation_313[0][0]']
#
#  conv2d_320 (Conv2D)            (None, 26, 26, 64)   27648       ['activation_316[0][0]']
#
#  batch_normalization_312 (Batch  (None, 26, 26, 32)  96          ['conv2d_315[0][0]']
#  Normalization)
#
#  batch_normalization_314 (Batch  (None, 26, 26, 32)  96          ['conv2d_317[0][0]']
#  Normalization)
#
#  batch_normalization_317 (Batch  (None, 26, 26, 64)  192         ['conv2d_320[0][0]']
#  Normalization)
#
#  activation_312 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_312[0][0]']
#
#  activation_314 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_314[0][0]']
#
#  activation_317 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_317[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 26, 26, 128)  0           ['activation_312[0][0]',
#                                                                   'activation_314[0][0]',
#                                                                   'activation_317[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 26, 26, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 26, 26, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 26, 26, 320)  0           ['block35_4[0][0]']
#
#  conv2d_324 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_321 (Batch  (None, 26, 26, 32)  96          ['conv2d_324[0][0]']
#  Normalization)
#
#  activation_321 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_321[0][0]']
#
#  conv2d_322 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_325 (Conv2D)            (None, 26, 26, 48)   13824       ['activation_321[0][0]']
#
#  batch_normalization_319 (Batch  (None, 26, 26, 32)  96          ['conv2d_322[0][0]']
#  Normalization)
#
#  batch_normalization_322 (Batch  (None, 26, 26, 48)  144         ['conv2d_325[0][0]']
#  Normalization)
#
#  activation_319 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_319[0][0]']
#
#  activation_322 (Activation)    (None, 26, 26, 48)   0           ['batch_normalization_322[0][0]']
#
#  conv2d_321 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_323 (Conv2D)            (None, 26, 26, 32)   9216        ['activation_319[0][0]']
#
#  conv2d_326 (Conv2D)            (None, 26, 26, 64)   27648       ['activation_322[0][0]']
#
#  batch_normalization_318 (Batch  (None, 26, 26, 32)  96          ['conv2d_321[0][0]']
#  Normalization)
#
#  batch_normalization_320 (Batch  (None, 26, 26, 32)  96          ['conv2d_323[0][0]']
#  Normalization)
#
#  batch_normalization_323 (Batch  (None, 26, 26, 64)  192         ['conv2d_326[0][0]']
#  Normalization)
#
#  activation_318 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_318[0][0]']
#
#  activation_320 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_320[0][0]']
#
#  activation_323 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_323[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 26, 26, 128)  0           ['activation_318[0][0]',
#                                                                   'activation_320[0][0]',
#                                                                   'activation_323[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 26, 26, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 26, 26, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 26, 26, 320)  0           ['block35_5[0][0]']
#
#  conv2d_330 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_327 (Batch  (None, 26, 26, 32)  96          ['conv2d_330[0][0]']
#  Normalization)
#
#  activation_327 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_327[0][0]']
#
#  conv2d_328 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_331 (Conv2D)            (None, 26, 26, 48)   13824       ['activation_327[0][0]']
#
#  batch_normalization_325 (Batch  (None, 26, 26, 32)  96          ['conv2d_328[0][0]']
#  Normalization)
#
#  batch_normalization_328 (Batch  (None, 26, 26, 48)  144         ['conv2d_331[0][0]']
#  Normalization)
#
#  activation_325 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_325[0][0]']
#
#  activation_328 (Activation)    (None, 26, 26, 48)   0           ['batch_normalization_328[0][0]']
#
#  conv2d_327 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_329 (Conv2D)            (None, 26, 26, 32)   9216        ['activation_325[0][0]']
#
#  conv2d_332 (Conv2D)            (None, 26, 26, 64)   27648       ['activation_328[0][0]']
#
#  batch_normalization_324 (Batch  (None, 26, 26, 32)  96          ['conv2d_327[0][0]']
#  Normalization)
#
#  batch_normalization_326 (Batch  (None, 26, 26, 32)  96          ['conv2d_329[0][0]']
#  Normalization)
#
#  batch_normalization_329 (Batch  (None, 26, 26, 64)  192         ['conv2d_332[0][0]']
#  Normalization)
#
#  activation_324 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_324[0][0]']
#
#  activation_326 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_326[0][0]']
#
#  activation_329 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_329[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 26, 26, 128)  0           ['activation_324[0][0]',
#                                                                   'activation_326[0][0]',
#                                                                   'activation_329[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 26, 26, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 26, 26, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 26, 26, 320)  0           ['block35_6[0][0]']
#
#  conv2d_336 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_333 (Batch  (None, 26, 26, 32)  96          ['conv2d_336[0][0]']
#  Normalization)
#
#  activation_333 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_333[0][0]']
#
#  conv2d_334 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_337 (Conv2D)            (None, 26, 26, 48)   13824       ['activation_333[0][0]']
#
#  batch_normalization_331 (Batch  (None, 26, 26, 32)  96          ['conv2d_334[0][0]']
#  Normalization)
#
#  batch_normalization_334 (Batch  (None, 26, 26, 48)  144         ['conv2d_337[0][0]']
#  Normalization)
#
#  activation_331 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_331[0][0]']
#
#  activation_334 (Activation)    (None, 26, 26, 48)   0           ['batch_normalization_334[0][0]']
#
#  conv2d_333 (Conv2D)            (None, 26, 26, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_335 (Conv2D)            (None, 26, 26, 32)   9216        ['activation_331[0][0]']
#
#  conv2d_338 (Conv2D)            (None, 26, 26, 64)   27648       ['activation_334[0][0]']
#
#  batch_normalization_330 (Batch  (None, 26, 26, 32)  96          ['conv2d_333[0][0]']
#  Normalization)
#
#  batch_normalization_332 (Batch  (None, 26, 26, 32)  96          ['conv2d_335[0][0]']
#  Normalization)
#
#  batch_normalization_335 (Batch  (None, 26, 26, 64)  192         ['conv2d_338[0][0]']
#  Normalization)
#
#  activation_330 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_330[0][0]']
#
#  activation_332 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_332[0][0]']
#
#  activation_335 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_335[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 26, 26, 128)  0           ['activation_330[0][0]',
#                                                                   'activation_332[0][0]',
#                                                                   'activation_335[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 26, 26, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 26, 26, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 26, 26, 320)  0           ['block35_7[0][0]']
#
# ...
#
#  conv2d_473 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_6_ac[0][0]']
#
#  batch_normalization_470 (Batch  (None, 5, 5, 192)   576         ['conv2d_473[0][0]']
#  Normalization)
#
#  activation_470 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_470[0][0]']
#
#  conv2d_474 (Conv2D)            (None, 5, 5, 224)    129024      ['activation_470[0][0]']
#
#  batch_normalization_471 (Batch  (None, 5, 5, 224)   672         ['conv2d_474[0][0]']
#  Normalization)
#
#  activation_471 (Activation)    (None, 5, 5, 224)    0           ['batch_normalization_471[0][0]']
#
#  conv2d_472 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_475 (Conv2D)            (None, 5, 5, 256)    172032      ['activation_471[0][0]']
#
#  batch_normalization_469 (Batch  (None, 5, 5, 192)   576         ['conv2d_472[0][0]']
#  Normalization)
#
#  batch_normalization_472 (Batch  (None, 5, 5, 256)   768         ['conv2d_475[0][0]']
#  Normalization)
#
#  activation_469 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_469[0][0]']
#
#  activation_472 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_472[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 5, 5, 448)    0           ['activation_469[0][0]',
#                                                                   'activation_472[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 5, 5, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 5, 5, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 5, 5, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_477 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_474 (Batch  (None, 5, 5, 192)   576         ['conv2d_477[0][0]']
#  Normalization)
#
#  activation_474 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_474[0][0]']
#
#  conv2d_478 (Conv2D)            (None, 5, 5, 224)    129024      ['activation_474[0][0]']
#
#  batch_normalization_475 (Batch  (None, 5, 5, 224)   672         ['conv2d_478[0][0]']
#  Normalization)
#
#  activation_475 (Activation)    (None, 5, 5, 224)    0           ['batch_normalization_475[0][0]']
#
#  conv2d_476 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_479 (Conv2D)            (None, 5, 5, 256)    172032      ['activation_475[0][0]']
#
#  batch_normalization_473 (Batch  (None, 5, 5, 192)   576         ['conv2d_476[0][0]']
#  Normalization)
#
#  batch_normalization_476 (Batch  (None, 5, 5, 256)   768         ['conv2d_479[0][0]']
#  Normalization)
#
#  activation_473 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_473[0][0]']
#
#  activation_476 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_476[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 5, 5, 448)    0           ['activation_473[0][0]',
#                                                                   'activation_476[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 5, 5, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 5, 5, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 5, 5, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_481 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_478 (Batch  (None, 5, 5, 192)   576         ['conv2d_481[0][0]']
#  Normalization)
#
#  activation_478 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_478[0][0]']
#
#  conv2d_482 (Conv2D)            (None, 5, 5, 224)    129024      ['activation_478[0][0]']
#
#  batch_normalization_479 (Batch  (None, 5, 5, 224)   672         ['conv2d_482[0][0]']
#  Normalization)
#
#  activation_479 (Activation)    (None, 5, 5, 224)    0           ['batch_normalization_479[0][0]']
#
#  conv2d_480 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_483 (Conv2D)            (None, 5, 5, 256)    172032      ['activation_479[0][0]']
#
#  batch_normalization_477 (Batch  (None, 5, 5, 192)   576         ['conv2d_480[0][0]']
#  Normalization)
#
#  batch_normalization_480 (Batch  (None, 5, 5, 256)   768         ['conv2d_483[0][0]']
#  Normalization)
#
#  activation_477 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_477[0][0]']
#
#  activation_480 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_480[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 5, 5, 448)    0           ['activation_477[0][0]',
#                                                                   'activation_480[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 5, 5, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 5, 5, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 5, 5, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_485 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_482 (Batch  (None, 5, 5, 192)   576         ['conv2d_485[0][0]']
#  Normalization)
#
#  activation_482 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_482[0][0]']
#
#  conv2d_486 (Conv2D)            (None, 5, 5, 224)    129024      ['activation_482[0][0]']
#
#  batch_normalization_483 (Batch  (None, 5, 5, 224)   672         ['conv2d_486[0][0]']
#  Normalization)
#
#  activation_483 (Activation)    (None, 5, 5, 224)    0           ['batch_normalization_483[0][0]']
#
#  conv2d_484 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_487 (Conv2D)            (None, 5, 5, 256)    172032      ['activation_483[0][0]']
#
#  batch_normalization_481 (Batch  (None, 5, 5, 192)   576         ['conv2d_484[0][0]']
#  Normalization)
#
#  batch_normalization_484 (Batch  (None, 5, 5, 256)   768         ['conv2d_487[0][0]']
#  Normalization)
#
#  activation_481 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_481[0][0]']
#
#  activation_484 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_484[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 5, 5, 448)    0           ['activation_481[0][0]',
#                                                                   'activation_484[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 5, 5, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 5, 5, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 5, 5, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 5, 5, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 5, 5, 1536)   0           ['conv_7b_bn[0][0]']
#
# ==================================================================================================
# Total params: 54,336,736
# Trainable params: 54,276,192
# Non-trainable params: 60,544
# __________________________________________________________________________________________________

# %%
from keras import models
from keras import layers
from tensorflow import keras
from tensorflow.keras.layers import Dense,Conv2D,Flatten,MaxPooling2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import RMSprop

optimizer = keras.optimizers.Adam(lr=0.003, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)

model = models.Sequential()

model.add(Conv2D(3, (3, 3), padding="same", activation="relu", input_shape=(img_width, img_height, 1)))

model.add(conv_base)

model.add(GlobalAveragePooling2D())

model.add(layers.Flatten())
#model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(1024, activation='relu'))
#model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
#model.add(layers.BatchNormalization())

#model.add(layers.Dense(4096, activation='relu'))
#model.add(Dense(activation = 'relu', units = 64))
model.add(Dense(3,activation="softmax"))
model.compile(optimizer = optimizer, loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
#model.compile(optimizer = RMSprop(lr=1e-2) , loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

conv_base.trainable = False
#fine-tuning
'''
conv_base.trainable = True

set_trainable = False
for layer in conv_base.layers:
  if layer.name == 'block5_conv1':
    set_trainable = True
  if set_trainable:
    layer.trainable = True
  else:
    layer.trainable = False
'''
model.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_489 (Conv2D)         (None, 229, 229, 3)       30
#
#  inception_resnet_v2 (Functi  (None, 5, 5, 1536)       54336736
#  onal)
#
#  global_average_pooling2d_4   (None, 1536)             0
#  (GlobalAveragePooling2D)
#
#  flatten_5 (Flatten)         (None, 1536)              0
#
#  dropout_10 (Dropout)        (None, 1536)              0
#
#  dense_14 (Dense)            (None, 1024)              1573888
#
#  dropout_11 (Dropout)        (None, 1024)              0
#
#  dense_15 (Dense)            (None, 1024)              1049600
#
#  dropout_12 (Dropout)        (None, 1024)              0
#
#  dense_16 (Dense)            (None, 3)                 3075
#
# =================================================================
# Total params: 56,963,329
# Trainable params: 2,626,593
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau

#early stopping
early = EarlyStopping(monitor="val_loss",
                      mode="auto",
                      patience=9)

learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience = 4, verbose=1,factor=1e-1, min_lr=0.000001)

checkpoint_filepath = 'checkpointCNN4.h5'
Model_check = keras.callbacks.ModelCheckpoint(
    checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

checkpoint_filepath1 = 'checkpointCNN5.h5'
Model_check1 = keras.callbacks.ModelCheckpoint(
    checkpoint_filepath1, monitor='val_loss', verbose=1, save_best_only=False, mode='auto')

callbacks_list = [ early, learning_rate_reduction]

# %%
history = model.fit(train,
                    batch_size=16,
                    epochs=30,
                    validation_data=valid,
                    callbacks=[early,learning_rate_reduction, Model_check, Model_check1])
# Out:
# Epoch 1/30
# 229/229 [==============================] - ETA: 0s - loss: 0.9937 - accuracy: 0.6067
# Epoch 1: val_loss improved from inf to 0.32235, saving model to checkpointCNN4.h5
#
# Epoch 1: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 216s 884ms/step - loss: 0.9937 - accuracy: 0.6067 - val_loss: 0.3223 - val_accuracy: 0.9195 - lr: 0.0030
# Epoch 2/30
# 229/229 [==============================] - ETA: 0s - loss: 0.2100 - accuracy: 0.9317
# Epoch 2: val_loss improved from 0.32235 to 0.15758, saving model to checkpointCNN4.h5
#
# Epoch 2: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 198s 864ms/step - loss: 0.2100 - accuracy: 0.9317 - val_loss: 0.1576 - val_accuracy: 0.9464 - lr: 0.0030
# Epoch 3/30
# 229/229 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.9568
# Epoch 3: val_loss improved from 0.15758 to 0.15505, saving model to checkpointCNN4.h5
#
# Epoch 3: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 198s 863ms/step - loss: 0.1212 - accuracy: 0.9568 - val_loss: 0.1551 - val_accuracy: 0.9483 - lr: 0.0030
# Epoch 4/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0975 - accuracy: 0.9623
# Epoch 4: val_loss improved from 0.15505 to 0.12437, saving model to checkpointCNN4.h5
#
# Epoch 4: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 198s 863ms/step - loss: 0.0975 - accuracy: 0.9623 - val_loss: 0.1244 - val_accuracy: 0.9540 - lr: 0.0030
# Epoch 5/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0951 - accuracy: 0.9650
# Epoch 5: val_loss did not improve from 0.12437
#
# Epoch 5: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 855ms/step - loss: 0.0951 - accuracy: 0.9650 - val_loss: 0.1342 - val_accuracy: 0.9502 - lr: 0.0030
# Epoch 6/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0920 - accuracy: 0.9680
# Epoch 6: val_loss improved from 0.12437 to 0.11861, saving model to checkpointCNN4.h5
#
# Epoch 6: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 198s 864ms/step - loss: 0.0920 - accuracy: 0.9680 - val_loss: 0.1186 - val_accuracy: 0.9598 - lr: 0.0030
# Epoch 7/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9645
# Epoch 7: val_loss did not improve from 0.11861
#
# Epoch 7: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 855ms/step - loss: 0.0931 - accuracy: 0.9645 - val_loss: 0.1555 - val_accuracy: 0.9444 - lr: 0.0030
# Epoch 8/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9675
# Epoch 8: val_loss did not improve from 0.11861
#
# Epoch 8: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 854ms/step - loss: 0.0837 - accuracy: 0.9675 - val_loss: 0.1623 - val_accuracy: 0.9444 - lr: 0.0030
# Epoch 9/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0896 - accuracy: 0.9697
# Epoch 9: val_loss did not improve from 0.11861
#
# Epoch 9: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 853ms/step - loss: 0.0896 - accuracy: 0.9697 - val_loss: 0.1310 - val_accuracy: 0.9521 - lr: 0.0030
# Epoch 10/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.9699
# Epoch 10: val_loss improved from 0.11861 to 0.11629, saving model to checkpointCNN4.h5
#
# Epoch 10: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 197s 861ms/step - loss: 0.0793 - accuracy: 0.9699 - val_loss: 0.1163 - val_accuracy: 0.9579 - lr: 0.0030
# Epoch 11/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9705
# Epoch 11: val_loss did not improve from 0.11629
#
# Epoch 11: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 854ms/step - loss: 0.0786 - accuracy: 0.9705 - val_loss: 0.1372 - val_accuracy: 0.9483 - lr: 0.0030
# Epoch 12/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0754 - accuracy: 0.9740
# Epoch 12: val_loss did not improve from 0.11629
#
# Epoch 12: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 855ms/step - loss: 0.0754 - accuracy: 0.9740 - val_loss: 0.1378 - val_accuracy: 0.9502 - lr: 0.0030
# Epoch 13/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.9705
# Epoch 13: val_loss improved from 0.11629 to 0.11518, saving model to checkpointCNN4.h5
#
# Epoch 13: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 198s 862ms/step - loss: 0.0761 - accuracy: 0.9705 - val_loss: 0.1152 - val_accuracy: 0.9521 - lr: 0.0030
# Epoch 14/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.9732
# Epoch 14: val_loss did not improve from 0.11518
#
# Epoch 14: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 855ms/step - loss: 0.0711 - accuracy: 0.9732 - val_loss: 0.1171 - val_accuracy: 0.9559 - lr: 0.0030
# Epoch 15/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0686 - accuracy: 0.9768
# Epoch 15: val_loss improved from 0.11518 to 0.11044, saving model to checkpointCNN4.h5
#
# Epoch 15: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 198s 863ms/step - loss: 0.0686 - accuracy: 0.9768 - val_loss: 0.1104 - val_accuracy: 0.9521 - lr: 0.0030
# Epoch 16/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0649 - accuracy: 0.9762
# Epoch 16: val_loss improved from 0.11044 to 0.09531, saving model to checkpointCNN4.h5
#
# Epoch 16: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 198s 864ms/step - loss: 0.0649 - accuracy: 0.9762 - val_loss: 0.0953 - val_accuracy: 0.9617 - lr: 0.0030
# Epoch 17/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0873 - accuracy: 0.9653
# Epoch 17: val_loss did not improve from 0.09531
#
# Epoch 17: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 856ms/step - loss: 0.0873 - accuracy: 0.9653 - val_loss: 0.1327 - val_accuracy: 0.9521 - lr: 0.0030
# Epoch 18/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9773
# Epoch 18: val_loss did not improve from 0.09531
#
# Epoch 18: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 856ms/step - loss: 0.0599 - accuracy: 0.9773 - val_loss: 0.1323 - val_accuracy: 0.9540 - lr: 0.0030
# Epoch 19/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0686 - accuracy: 0.9770
# Epoch 19: val_loss did not improve from 0.09531
#
# Epoch 19: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 856ms/step - loss: 0.0686 - accuracy: 0.9770 - val_loss: 0.1225 - val_accuracy: 0.9521 - lr: 0.0030
# Epoch 20/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0632 - accuracy: 0.9754
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00030000000260770325.
#
# Epoch 20: val_loss did not improve from 0.09531
#
# Epoch 20: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 197s 858ms/step - loss: 0.0632 - accuracy: 0.9754 - val_loss: 0.1208 - val_accuracy: 0.9521 - lr: 0.0030
# Epoch 21/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9792
# Epoch 21: val_loss did not improve from 0.09531
#
# Epoch 21: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 857ms/step - loss: 0.0589 - accuracy: 0.9792 - val_loss: 0.1029 - val_accuracy: 0.9559 - lr: 3.0000e-04
# Epoch 22/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9787
# Epoch 22: val_loss did not improve from 0.09531
#
# Epoch 22: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 855ms/step - loss: 0.0568 - accuracy: 0.9787 - val_loss: 0.1080 - val_accuracy: 0.9559 - lr: 3.0000e-04
# Epoch 23/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9790
# Epoch 23: val_loss did not improve from 0.09531
#
# Epoch 23: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 857ms/step - loss: 0.0570 - accuracy: 0.9790 - val_loss: 0.1096 - val_accuracy: 0.9559 - lr: 3.0000e-04
# Epoch 24/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9790
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.000000142492354e-05.
#
# Epoch 24: val_loss did not improve from 0.09531
#
# Epoch 24: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 855ms/step - loss: 0.0580 - accuracy: 0.9790 - val_loss: 0.1115 - val_accuracy: 0.9559 - lr: 3.0000e-04
# Epoch 25/30
# 229/229 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.9795
# Epoch 25: val_loss did not improve from 0.09531
#
# Epoch 25: saving model to checkpointCNN5.h5
# 229/229 [==============================] - 196s 855ms/step - loss: 0.0562 - accuracy: 0.9795 - val_loss: 0.1100 - val_accuracy: 0.9559 - lr: 3.0000e-05

# %%
from keras.models import load_model
model = load_model('checkpointCNN4.h5')
test_accu = model.evaluate(test)
print('The testing accuracy is :',test_accu[1]*100, '%')
# Out:
# 66/66 [==============================] - 25s 318ms/step - loss: 0.1688 - accuracy: 0.9618
# The testing accuracy is : 96.17956280708313 %

# %%
import numpy as np
rounded_labels=np.argmax(preds, axis=1)
rounded_labels[1]
# Out:
# 0

# %%
from sklearn.metrics import confusion_matrix
cmm = confusion_matrix(rounded_labels, test.classes)
cmm
# Out:
# array([[322,   0,   1],
#        [  2, 361,  37],
#        [  2,   0, 322]])

# %%
from sklearn.metrics import classification_report,confusion_matrix
cm = pd.DataFrame(data=confusion_matrix(test.classes, rounded_labels, labels=[0, 1, 2]),index=["Actual COVID-19", "Actual Normal", "Actual Pneumonia"],
columns=["Predicted COVID-19", "Predicted Normal", "Predicted Pneumonia"])
import seaborn as sns
sns.heatmap(cm,annot=True,fmt="d")

# %%
print(classification_report(y_true=test.classes,y_pred=rounded_labels,target_names =['COVID-19','NORMAL','Pneumonia']))
# Out:
#               precision    recall  f1-score   support
#
#     COVID-19       1.00      0.99      0.99       326
#       NORMAL       0.90      1.00      0.95       361
#    Pneumonia       0.99      0.89      0.94       360
#
#     accuracy                           0.96      1047
#    macro avg       0.96      0.96      0.96      1047
# weighted avg       0.96      0.96      0.96      1047
